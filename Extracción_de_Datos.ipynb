# %% [markdown]
# <a href="https://colab.research.google.com/github/JarlynLoza/Actividad_1/blob/main/Extracci%C3%B3n_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a0a57b4b-4e67-44df-af2b-2c4d48a6518d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0a57b4b-4e67-44df-af2b-2c4d48a6518d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %% [markdown]
# ##Filtro 1

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE_VENDEDOR"]=="DIEGO ARMANDO LEON DURAN"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05  DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05  DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05  DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05  DIEGO ARMANDO LEON DURAN
# ...      ...        ...                       ...
# 519   F38005 2022-04-27  DIEGO ARMANDO LEON DURAN
# 580   F38141 2022-05-12  DIEGO ARMANDO LEON DURAN
# 731   F38459 2022-06-24  DIEGO ARMANDO LEON DURAN
# 851   F38665 2022-07-26  DIEGO ARMANDO LEON DURAN
# 1296  F39592 2022-11-16  DIEGO ARMANDO LEON DURAN
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                    OMAR RODRIGUEZ GOMEZ     1    TP0001
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %%
#Convertir archivo filtrado a csv
filtro1.to_csv("Filtro1.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro1.csv")

# %% [markdown]
# ##Filtro 2

# %%
#Filtro por filas
filtro2=df.iloc[519:851,:]        #Filas consecutivas
#filtro2=df.iloc[[8,24,100], : ] #Filas no consecutivas
filtro2
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 519  F38005 2022-04-27   DIEGO ARMANDO LEON DURAN
# 520  F38008 2022-04-28  LETICIA RAMIREZ HERNANDEZ
# 521  F38012 2022-04-28  LETICIA RAMIREZ HERNANDEZ
# 522  F38014 2022-04-28  LETICIA RAMIREZ HERNANDEZ
# 523  F38021 2022-04-28             ALFREDO CANELA
# ..      ...        ...                        ...
# 846  F38652 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 847  F38652 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 848  F38653 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 849  F38657 2022-07-25             ALFREDO CANELA
# 850  F38663 2022-07-26  LETICIA RAMIREZ HERNANDEZ
#
#                                  NOMBRE_CLIENTE  CANT       CVE_ART  \
# 519                          MARCEGAGLIA MEXICO     5      TUE00261
# 520  COCINAS Y EQUIPOS INOXIDABLES DE QUERETARO     2      TUA00437
# 521                        JOSE LUIS PIÑA MEJIA     1      TUE00336
# 522                    SATURNINO CASTRO SANCHEZ     5       PT00083
# ...

# %%
#Convertir archivo filtrado a csv
filtro2.to_csv("Filtro2.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro2.csv")

# %% [markdown]
# ##Filtro3

# %%
#Filtro por columnas
#filtro3=df.iloc[ : , 50:85]  #Columnas consecutivas
filtro3=df.iloc[:,[1,3,5]] #Columnas no consecutivas
filtro3
# Out:
#       FECHA_DOC                NOMBRE_CLIENTE       CVE_ART
# 0    2022-01-05            PÚBLICO EN GENERAL      TUE00244
# 1    2022-01-05  JUAN ANTONIO RESENDIZ UGALDE      TUA00028
# 2    2022-01-05     ANA BARBARA CRUZ PALACIOS        TP0007
# 3    2022-01-05          OMAR RODRIGUEZ GOMEZ        TP0001
# 4    2022-01-05            PÚBLICO EN GENERAL       BP00242
# ...         ...                           ...           ...
# 1421 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ  CS12F1040A00
# 1422 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ  CS12H1050A00
# 1423 2022-12-23          SEVEN DAYS ALL SPORT      TUE00394
# 1424 2022-12-23           REVUELTA MONTECARLO      TUA00470
# 1425 2022-12-23                CPEG SOLUTIONS       RB00007
#
# [1426 rows x 3 columns]

# %%
#Convertir archivo filtrado a csv
filtro3.to_csv("Filtro3.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro3.csv")

# %% [markdown]
# ##Filtro 4

# %%
df1=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=1)
df1
# Out:
#            CVE_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# FECHA_DOC
# 2022-01-05  F37034  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 2022-01-05  F37036  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2022-01-05  F37041   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 2022-01-05  F37042   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 2022-01-05  F37043  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...            ...                        ...                           ...
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39834  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 2022-12-23  F39835  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 2022-12-23  F39837  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 2022-12-23  F39838         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
# ...

# %%
#Paso 2:Aplicamos filtro de filas vs columnas
filtro4=df1.loc[["2022-01-05","2022-12-23"],["CVE_ART"]]
filtro4
# Out:
#                  CVE_ART
# FECHA_DOC
# 2022-01-05      TUE00244
# 2022-01-05      TUA00028
# 2022-01-05        TP0007
# 2022-01-05        TP0001
# 2022-01-05       BP00242
# 2022-01-05       BP00243
# 2022-01-05       RP00165
# 2022-01-05        TP0001
# 2022-01-05      TUE00207
# 2022-01-05      TUE00207
# 2022-01-05      TUE00207
# 2022-01-05      TUE00207
# 2022-01-05      TUE00207
# 2022-01-05       BO00051
# 2022-01-05       BC00023
# 2022-01-05       PT00070
# 2022-01-05        TP0011
# 2022-01-05  PJ31C1F1AA00
# 2022-01-05      WRE-2133
# 2022-01-05      WRE-2774
# 2022-01-05      WRE-4885
# 2022-12-23      TUA00325
# 2022-12-23       RB00007
# 2022-12-23       TP00018
# 2022-12-23       BP00006
# 2022-12-23  PJ31Q1G1A400
# 2022-12-23       BL00002
# 2022-12-23       BN00145
# 2022-12-23       BN00146
# 2022-12-23       PT00079
# 2022-12-23  CS12F1040A00
# 2022-12-23  CS12H1050A00
# 2022-12-23      TUE00394
# 2022-12-23      TUA00470
# 2022-12-23       RB00007

# %%
#Convertir archivo filtrado a csv
filtro4.to_csv("Filtro4.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro4.csv")

# %% [markdown]
# ##Filtro 5

# %%
#Filtro de cabecera
filtro5=df.head(30)
filtro5
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0   F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1   F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2   F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3   F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6   F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8   F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9   F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10  F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# 11  F37051 2022-01-05   DIEGO ARMANDO LEON DURAN
# 12  F37052 2022-01-05   DIEGO ARMANDO LEON DURAN
# 13  F37053 2022-01-05   DIEGO ARMANDO LEON DURAN
# 14  F37054 2022-01-05   DIEGO ARMANDO LEON DURAN
# 15  F37058 2022-01-05   DIEGO ARMANDO LEON DURAN
# 16  F37059 2022-01-05   DIEGO ARMANDO LEON DURAN
# 17  F37060 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...

# %%
#Convertir archivo filtrado a csv
filtro5.to_csv("Filtro5.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro5.csv")

# %% [markdown]
# ##Filtro 6

# %%
#Filtro por comparación
filtro6=df[df["PRECIO_UNITARIO"]>500]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2               ANA BARBARA CRUZ PALACIOS     7        TP0007
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1       RP00165
# 8                      FIDEICOMISO F/1596     1      TUE00207
# ...

# %%
#Convertir archivo filtrado a csv
filtro6.to_csv("Filtro6.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro6.csv")

# %% [markdown]
# ##Filtro 7

# %%
#Filtro Y
filtro7=df[(df["PRECIO_UNITARIO"]>300)& (df["FECHA_DOC"]=="2022-12-23")]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1412  F39824 2022-12-23             ALFREDO CANELA
# 1413  F39826 2022-12-23         AARON NUÑO CORDOVA
# 1414  F39828 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                   NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1412                   MEGO AFEK     1      TUA00325
# 1413              CPEG SOLUTIONS     5       RB00007
# ...

# %%
#Convertir archivo filtrado a csv
filtro7.to_csv("Filtro7.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro7.csv")

# %% [markdown]
# ##Filtro 8

# %%
#Filtro o
filtro8=df[(df["COSTO_UNITARIO_CALCULADO"]< 2000)| (df["FECHA_DOC"]=="2022-12-23")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#Convertir archivo filtrado a csv
filtro8.to_csv("Filtro8.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro8.csv")

# %% [markdown]
# ##Filtro 9

# %%
#filtro not
filtro9 = df[~(df['COSTO_TOTAL_CALCULADO'] < 200) & ~(df['FECHA_DOC'] == '2022-12-23')]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1406  F39813 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1407  F39815 2022-12-22             ALFREDO CANELA
# 1409  F39816 2022-12-22             ALFREDO CANELA
# 1410  F39817 2022-12-22  LETICIA RAMIREZ HERNANDEZ
# 1411  F39820 2022-12-22         AARON NUÑO CORDOVA
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1                          JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2                             ANA BARBARA CRUZ PALACIOS     7        TP0007
# 4                                    PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
#Convertir archivo filtrado a csv
filtro9.to_csv("Filtro9.csv")

# %%
#Convertir archivo filtrado a CSV
from google.colab import files

files.download("Filtro9.csv")
